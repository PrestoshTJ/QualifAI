# %% [markdown]
# <a href="https://colab.research.google.com/github/PrestoshTJ/QualifAI/blob/main/webscraper.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pymongo

# %%
# Created With help from https://www.youtube.com/watch?v=-H-JCgvV0z8
import requests
from bs4 import BeautifulSoup
import random
import pandas as pd
from collections import deque
import time
import re
import json
import pymongo



keywords = {"Computer%20Science", "Engineering", "Business%20Administration", "Marketing", "Graphic%20Design", "Data%20Science", "Information%20Technology", "Communications", "Finance", "Environmental%20Science"}
# Out:
# Collecting pymongo
#   Downloading pymongo-4.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (22 kB)
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo)
#   Downloading dnspython-2.7.0-py3-none-any.whl.metadata (5.8 kB)
# Downloading pymongo-4.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 14.6 MB/s eta 0:00:00
# Downloading dnspython-2.7.0-py3-none-any.whl (313 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.6/313.6 kB 25.5 MB/s eta 0:00:00
# Installing collected packages: dnspython, pymongo
# Successfully installed dnspython-2.7.0 pymongo-4.10.1

# %%
id_list = {keyword: [] for keyword in keywords}




for keyword in keywords:
  q = deque()
  for i in range(0, 51, 10):
    q.append(i)
  while q:
    i = q.popleft()
    list_url = f"https://www.linkedin.com/jobs-guest/jobs/api/seeMoreJobPostings/search?keywords={keyword}&start={i}"

    response = requests.get(list_url)
    if not response.status_code == 200:
        time.sleep(2)
        q.append(i)
        continue
    list_data = response.text
    list_soup = BeautifulSoup(list_data, "html.parser")
    page_jobs = list_soup.find_all("li")

    for job in page_jobs:
      base_card_div = job.find("div", {"class": "base-card"})
      job_id = base_card_div.get("data-entity-urn").split(":")[3]
      id_list[keyword].append(job_id)
  print(len(id_list[keyword]))
# Out:
# 60
# 60
# 60
# 60
# 60
# 60
# 58
# 60
# 60
# 60

# %%
print(len(id_list))
job_list = []
# Out:
# 10

# %%
q = deque()
for keyword in id_list:
  word = " ".join(keyword.split("%20"))
  for job_id in id_list[keyword]:
    q.append((job_id, word))

# %%
while q:
  job = q.popleft()
  job_id = job[0]
  keyword = job[1]
  job_url = f"https://www.linkedin.com/jobs-guest/jobs/api/jobPosting/{job_id}"
  job_response = requests.get(job_url)
  job_soup = BeautifulSoup(job_response.text, "html.parser")
  job_post = {}
  if not job_response.status_code == 200:
    q.append((job_id, keyword))
    time.sleep(2)
    continue
  job_post["job_id"] = job_id
  job_post["keyword"] = keyword
  try:
    job_post["job_title"] = job_soup.find("h2", {"class": "top-card-layout__title font-sans text-lg papabear:text-xl font-bold leading-open text-color-text mb-0 topcard__title"}).text.strip()
  except:
    job_post["job_title"] = None
  try:
    job_post["company_name"] = job_soup.find("a", {"class": "topcard__org-name-link topcard__flavor--black-link"}).text.strip()
  except:
    job_post["company_name"] = None
  try:
    job_post["time_posted"] = job_soup.find("span", {"class": "posted-time-ago__text topcard__flavor--metadata"}).text.strip()
  except:
    job_post["time_posted"] = None
  try:
    job_post["num_applicants"] = job_soup.find("span", {"class": "num-applicants__caption topcard__flavor--metadata topcard__flavor--bullet"}).text.strip();
  except:
      try:
        job_post["num_applicants"] = job_soup.find("figcaption", {"class": "num-applicants__caption"}).text.strip();
      except:
        job_post["num_applicants"] = None
  try:
    job_post["location"] = job_soup.find("span", {"class": "topcard__flavor topcard__flavor--bullet"}).text.strip()
  except:
    job_post["location"] = None
  try:
    job_post["experience_level"] = job_soup.find_all("span", {"class": "description__job-criteria-text description__job-criteria-text--criteria"})[0].text.strip()
  except:
    job_post["experience_level"] = None
  try:
    job_post["employment_type"] = job_soup.find_all("span", {"class": "description__job-criteria-text description__job-criteria-text--criteria"})[1].text.strip()
  except:
    job_post["employment_type"] = None

  print(len(q))
  print(len(job_list))
  job_list.append(job_post)
# Out:
# 597
# 0
# 596
# 1
# 595
# 2
# 594
# 3
# 593
# 4
# 592
# 5
# 591
# 6
# 590
# 7
# 589
# 8
# 588
# 9
# 587
# 10
# 586
# 11
# 585
# 12
# 584
# 13
# 583
# 14
# 582
# 15
# 581
# 16
# 580
# 17
# 579
# 18
# 578
# 19
# 577
# 20
# 576
# 21
# 575
# 22
# 574
# 23
# 573
# 24
# 572
# 25
# 571
# 26
# 570
# 27
# 569
# 28
# 568
# 29
# 567
# 30
# 566
# 31
# 565
# 32
# 564
# 33
# 563
# 34
# 562
# 35
# 561
# 36
# 560
# 37
# 559
# 38
# 558
# 39
# 557
# 40
# 556
# 41
# 555
# 42
# 554
# 43
# 553
# 44
# 552
# 45
# 551
# 46
# 550
# 47
# 549
# 48
# 548
# 49
# 547
# 50
# 546
# 51
# 545
# 52
# 544
# 53
# 543
# 54
# 542
# 55
# 541
# 56
# 540
# 57
# 539
# 58
# 538
# 59
# 537
# 60
# 536
# 61
# 535
# 62
# 534
# 63
# 533
# 64
# 532
# 65
# 531
# 66
# 530
# 67
# 529
# 68
# 528
# 69
# 527
# 70
# 526
# 71
# 525
# 72
# 524
# 73
# 523
# 74
# 522
# 75
# 521
# 76
# 520
# 77
# 519
# 78
# 518
# 79
# 517
# 80
# 516
# 81
# 515
# 82
# 514
# 83
# 513
# 84
# 512
# 85
# 511
# 86
# 510
# 87
# 509
# 88
# 508
# 89
# 507
# 90
# 506
# 91
# 505
# 92
# 504
# 93
# 503
# 94
# 502
# 95
# 501
# 96
# 500
# 97
# 499
# 98
# 498
# 99
# 497
# 100
# 496
# 101
# 495
# 102
# 494
# 103
# 493
# 104
# 492
# 105
# 491
# 106
# 490
# 107
# 489
# 108
# 488
# 109
# 487
# 110
# 486
# 111
# 485
# 112
# 484
# 113
# 483
# 114
# 482
# 115
# 481
# 116
# 480
# 117
# 479
# 118
# 478
# 119
# 477
# 120
# 476
# 121
# 475
# 122
# 474
# 123
# 473
# 124
# 472
# 125
# 471
# 126
# 470
# 127
# 469
# 128
# 468
# 114
# 483
# 113
# 484
# 112
# 485
# 111
# 486
# 110
# 487
# 109
# 488
# 108
# 489
# 107
# 490
# 106
# 491
# 105
# 492
# 104
# 493
# 103
# 494
# 102
# 495
# 101
# 496
# 100
# 497
# 99
# 498
# 98
# 499
# 97
# 500
# 96
# 501
# 95
# 502
# 94
# 503
# 93
# 504
# 92
# 505
# 91
# 506
# 90
# 507
# 89
# 508
# 88
# 509
# 87
# 510
# 86
# 511
# 85
# 512
# 84
# 513
# 83
# 514
# 82
# 515
# 81
# 516
# 80
# 517
# 79
# 518
# 78
# 519
# 77
# 520
# 76
# 521
# 75
# 522
# 74
# 523
# 73
# 524
# 72
# 525
# 71
# 526
# 70
# 527
# 69
# 528
# 68
# 529
# 67
# 530
# 66
# 531
# 65
# 532
# 64
# 533
# 63
# 534
# 62
# 535
# 61
# 536
# 60
# 537
# 59
# 538
# 58
# 539
# 57
# 540
# 56
# 541
# 55
# 542
# 54
# 543
# 53
# 544
# 52
# 545
# 51
# 546
# 50
# 547
# 49
# 548
# 48
# 549
# 47
# 550
# 46
# 551
# 45
# 552
# 44
# 553
# 43
# 554
# 42
# 555
# 41
# 556
# 40
# 557
# 39
# 558
# 38
# 559
# 37
# 560
# 36
# 561
# 35
# 562
# 34
# 563
# 33
# 564
# 32
# 565
# 31
# 566
# 30
# 567
# 29
# 568
# 28
# 569
# 27
# 570
# 26
# 571
# 25
# 572
# 24
# 573
# 23
# 574
# 22
# 575
# 21
# 576
# 20
# 577
# 19
# 578
# 18
# 579
# 17
# 580
# 16
# 581
# 15
# 582
# 14
# 583
# 13
# 584
# 12
# 585
# 11
# 586
# 10
# 587
# 9
# 588
# 8
# 589
# 7
# 590
# 6
# 591
# 5
# 592
# 4
# 593
# 3
# 594
# 2
# 595
# 1
# 596
# 0
# 597

# %%
print(len(q))
print(len(job_list))
print(job_list)
# Out:
# 0
# 598
# [{'job_id': '4045015071', 'keyword': 'Environmental Science', 'job_title': 'Environmental Health Specialist-4555023', 'company_name': 'State of Missouri', 'time_posted': '5 days ago', 'num_applicants': 'Be among the first 25 applicants', 'location': 'Poplar Bluff, MO', 'experience_level': 'Entry level', 'employment_type': 'Full-time'}, {'job_id': '4037388620', 'keyword': 'Environmental Science', 'job_title': 'Environmental Scientist Intern', 'company_name': 'Arcadis', 'time_posted': '1 week ago', 'num_applicants': '48 applicants', 'location': 'New York, NY', 'experience_level': 'Not Applicable', 'employment_type': 'Full-time'}, {'job_id': '4043815107', 'keyword': 'Environmental Science', 'job_title': 'Environmental Scientist', 'company_name': 'Environmental Research Group, LLC (ERG)', 'time_posted': '1 week ago', 'num_applicants': 'Be among the first 25 applicants', 'location': 'Baltimore, MD', 'experience_level': 'Mid-Senior level', 'employment_type': 'Full-time'}, {'job_id': '4033465087', 'keyword': 'Environmental Science', 'job_title': 'Graduate Environmental Scientist', 'company_name': 'Worley', 'time_posted': '2 weeks ago', 'num_applicants': '58 applicants', 'location': 'Houston, TX', 'experience_level': 'Not Applicable', 'employment_type': 'Full-time'}, {'job_id': '4038989519', 'keyword': 'Environmental Science', 'job_title': 'Wetland Delineator- Staff Biologist', 'company_name': 'SWCA Environmental Consultants', 'time_posted': '1 week ago', 'num_applicants': 'Be among the first 25 applicants', 'location': 'Texas County, OK', 'experience_level': 'Not Applicable', 'employment_type': 'Full-time'}, {'job_id': '4032099425', 'keyword': 'Environmental Science', 'job_title': 'Environmental Health Safety Specialist', 'company_name': 'Jane Roberts Consulting', 'time_posted': '2 weeks ago', 'num_applicants': '50 applicants', 'location': 'Greater Chicago Area', 'experience_level': 'Associate', 'employment_type': 'Full-time'}, {'job_id': '4046570963', 'keyword': 'Environmental Science', 'job_title': 'WILDLIFE TECHNICIAN', 'company_name': 'Arizona Game and Fish Department', 'time_posted': '1 day ago', 'num_applicants': 'Be among the first 25 applicants', 'location': 'Phoenix, AZ', 'experience_level': 'Entry level', 'employment_type': 'Full-time'}, {'job_id': '4044533682', 'keyword': 'Environmental Science', 'job_title': 'Interdisciplinary Natural Resource SPEC/ Rangeland Mgmt SPEC/ Forester/Soil Scientist/ Agronomist', 'company_name': 'USDA', 'time_posted': '6 days ago', 'num_applicants': 'Be among the first 25 applicants', 'location': 'Indiana, United States', 'experience_level': 'Entry level', 'employment_type': 'Full-time'}, {'job_id': '4009813848', 'keyword': 'Environmental Science', 'job_title': 'Graduate Environmental Scientist (Natural Resources)', 'company_name': 'GHD', 'time_posted': '4 days ago', 'num_applicants': '119 applicants', 'location': 'Tampa, FL', 'experience_level': 'Entry level', 'employment_type': 'Full-time'}, {'job_id': '4020400228', 'keyword': 'Environmental Science', 'job_title': 'Environmental Scientist', 'company_name': 'Evrhire', 'time_posted': '1 month ago', 'num_applicants': 'Over 200 applicants', 'location': 'Florida, United States', 'experience_level': 'Mid-Senior level', 'employment_type': 'Full-time'}, {'job_id': '4042779378', 'keyword': 'Environmental Science', 'job_title': 'ANALISTA AMBIENTAL', 'company_name': 'Associação Recreativa e Esportiva Copasul - AREC', 'time_posted': '1 week ago', 'num_applicants': 'Be among the first 25 applicants', 'location': 'Mississippi, United States', 'experience_level': 'Entry level', 'employment_type': 'Full-time'}, {'job_id': '4044533683', 'keyword': 'Environmental Science', 'job_title': 'Biologist', 'company_name': 'USDA', 'time_posted': '6 days ago', 'num_applicants': 'Be among the first 25 applicants', 'location': 'Fort Collins, CO', 'experience_level': 'Entry level', 'employment_type': 'Full-time'}, {'job_id': '4036960112', 'keyword': 'Environmental Science' ...

# %%
final = json.dumps(job_list, indent=2)

# %%
with open('Internships.json', 'w') as f:
  f.write(final)
